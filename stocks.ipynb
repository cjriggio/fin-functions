# %%
import pandas as pd
import numpy as np
import datetime 
from StockFunctions import StockData
from StockFunctions import DailyReturns

# %%
start = datetime.datetime(2019, 9, 1)
end = datetime.datetime(2019, 10, 1)

# %%
dominos = StockData('DPZ', start, end)
dominos
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2019-09-03  228.839996  223.399994  224.570007  226.869995  1225000.0
# 2019-09-04  241.190002  228.000000  228.240005  239.059998  1667600.0
# 2019-09-05  245.880005  240.740005  241.559998  244.830002  1116500.0
# 2019-09-06  246.330002  236.419998  245.110001  237.350006  1057600.0
# 2019-09-09  241.160004  235.869995  238.139999  239.199997   766900.0
# 2019-09-10  243.580002  231.850006  239.229996  243.570007   666800.0
# 2019-09-11  249.389999  242.119995  243.600006  249.089996   749300.0
# 2019-09-12  249.139999  245.869995  248.039993  246.789993   735800.0
# 2019-09-13  247.699997  243.729996  247.100006  245.050003   740800.0
# 2019-09-16  246.470001  243.080002  245.539993  244.789993  1064700.0
# 2019-09-17  245.199997  237.660004  243.850006  243.539993   658200.0
# 2019-09-18  245.210007  242.490005  244.149994  245.000000   495100.0
# ...

# %%
DailyReturns(dominos, 'Adj Close')
# Out:
# Date
# 2019-09-03         NaN
# 2019-09-04    0.053731
# 2019-09-05    0.024136
# 2019-09-06   -0.030552
# 2019-09-09    0.007794
# 2019-09-10    0.018269
# 2019-09-11    0.022663
# 2019-09-12   -0.006641
# 2019-09-13   -0.007050
# 2019-09-16   -0.001061
# 2019-09-17   -0.005106
# 2019-09-18    0.005995
# 2019-09-19    0.008204
# 2019-09-20    0.002470
# 2019-09-23   -0.005492
# 2019-09-24   -0.013360
# 2019-09-25   -0.006256
# 2019-09-26   -0.008242
# 2019-09-27    0.004176
# 2019-09-30    0.017175
# 2019-10-01    0.004824
# 2019-10-02   -0.016357
# Name: Adj Close, dtype: float64
